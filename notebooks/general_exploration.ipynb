# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append("../src") if "../src" not in sys.path else None 

from CANN_burak import CANN_burak
from CANN_sorscher import *

# %%
gc = grid_cell(phase_offset=0,orientation_offset=0,f=2.0)

n = 64
board = np.stack(np.meshgrid(np.linspace(-1/2, 1/2, n), np.linspace(-1/2, 1/2, n)), axis=-1)

plt.imshow(gc(board))#,origin='lower')

# %%
board = np.stack(np.meshgrid(np.linspace(0, 1, n), np.linspace(0, 1, n)), axis=-1)
plt.imshow(np.sum(board,axis=-1))

# %%
x = np.linspace(0,2*np.pi,100)
plt.plot(x,np.cos(x))

# %%
gc = grid_cell(phase_offset=0,orientation_offset=0)

n = 32
board = np.stack(np.meshgrid(np.linspace(-2*np.pi, 2*np.pi, n), np.linspace(-2*np.pi, 2*np.pi, n)), axis=-1)

plt.imshow(gc(board))
